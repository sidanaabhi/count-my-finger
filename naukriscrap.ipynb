# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import urllib.request
import math
import time
from pandas import DataFrame, Series
from urllib.request import Request, urlopen
import requests
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver import chrome
from selenium.common.exceptions import *
import datetime

# %%
jobs={"roles":[],
     "companies":[],
     "locations":[],
     "experience":[],
     "skills":[],
     "Dates":[],
     "PresentDate":[],
     "salary":[],}

# %%
MAX_PAGE_NUM = 50
MAX_PAGE_DIG = 3
driver=webdriver.Chrome('C:\Program Files\Google\Chrome\Application\chromedriver.exe')
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-10-45587533f205> in <module>
#       1 MAX_PAGE_NUM = 50
#       2 MAX_PAGE_DIG = 3
# ----> 3 driver=webdriver.Chrome('C:\Program Files\Google\Chrome\Application\chromedriver.exe')
#
# ~\anaconda3\envs\env\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      74
#      75         try:
# ---> 76             RemoteWebDriver.__init__(
#      77                 self,
#      78                 command_executor=ChromeRemoteConnection(
#
# ~\anaconda3\envs\env\lib\site-packages\selenium\webdriver\remote\webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     155             warnings.warn("Please use FirefoxOptions to set browser profile",
#     156                           DeprecationWarning, stacklevel=2)
# --> 157         self.start_session(capabilities, browser_profile)
#     158         self._switch_to = SwitchTo(self)
#     159         self._mobile = Mobile(self)
#
# ~\anaconda3\envs\env\lib\site-packages\selenium\webdriver\remote\webdriver.py in start_session(self, capabilities, browser_profile)
#     250         parameters = {"capabilities": w3c_caps,
#     251                       "desiredCapabilities": capabilities}
# --> 252         response = self.execute(Command.NEW_SESSION, parameters)
#     253         if 'sessionId' not in response:
#     254             response = response['value']
#
# ~\anaconda3\envs\env\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\envs\env\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# SessionNotCreatedException: Message: session not created: This version of ChromeDriver only supports Chrome version 85

# %%
for i in range(1, MAX_PAGE_NUM+1):
    page_num = (MAX_PAGE_DIG - len(str(i))) * "0" + str(i)
    url="https://www.naukri.com/data-scientist-jobs-"+page_num+"?k=data%20scientist"
    driver.get(url)
    time.sleep(3)
    lst=driver.find_elements_by_css_selector(".jobTuple.bgWhite.br4.mb-8")
    
    for job in lst:
        driver.implicitly_wait(10)
        try:
            role=job.find_element_by_css_selector("a.title.fw500.ellipsis").text
            company=job.find_element_by_css_selector("a.subTitle.ellipsis.fleft").text
            location=job.find_element_by_css_selector(".fleft.grey-text.br2.placeHolderLi.location").text
            salaries=job.find_element_by_css_selector(".fleft.grey-text.br2.placeHolderLi.salary").text
            exp=job.find_element_by_css_selector(".fleft.grey-text.br2.placeHolderLi.experience").text
            date=job.find_element_by_css_selector(".type.br2.fleft.grey").text
            skills=job.find_element_by_css_selector(".tags.has-description").text 
        except NoSuchElementException:
             pass
        today=datetime.datetime.today().strftime('%Y-%m-%d')
        jobs["roles"].append(role)
        jobs["companies"].append(company)
        jobs["locations"].append(location)
        jobs["experience"].append(exp)
        jobs["salary"].append(salaries)
        jobs["Dates"].append(date)
        jobs["PresentDate"].append(today)
        jobs["skills"].append(skills)

# %%
df1=pd.DataFrame(jobs)
df1
# Out:
#                                                  roles  \
# 0    Immediate opening For Data Scientist/Data Analyst
# 1              Data Scientist - Machine Learning/APICS
# 2            Data Scientist - Machine Learning/ Python
# 3                                Senior Data Scientist
# 4    Data Scientist - Machine Learning/Statistical ...
# ..                                                 ...
# 995                                Senior Data Analyst
# 996       Data Analyst-Machine Learning Developer/Lead
# 997                      Technical BA – DATA Analytics
# 998                                Senior Data Analyst
# 999                                  Sr . Data Analyst
#
#                                              companies  \
# 0    CAIA-Center For Artificial Intelligence & Adva...
# 1                                    CarbyneTech India
# 2                                    CarbyneTech India
# 3                    Flipkart Internet Private Limited
# 4                        Lericon Informatics Pvt. Ltd.
# ..                                                 ...
# 995                                      sRide Carpool
# 996                            Prowesstics IT services
# 997               CONDUENT BUSINESS SERVICES INDIA LLP
# 998                                           Snaphunt
# 999                   Larsen & Toubro Infotech Limited
#
#                                locations experience  \
# 0    Chennai, Pune, Bengaluru, Hyderabad    0-3 Yrs
# 1                              Hyderabad    3-8 Yrs
# 2                              Hyderabad    3-8 Yrs
# 3                              Bengaluru    2-7 Yrs
# 4                    Delhi/NCR Delhi NCR    5-8 Yrs
# ..                                   ...        ...
# 995                                 Pune    3-8 Yrs
# 996                              Chennai    3-8 Yrs
# 997                Bengaluru(Whitefield)   6-10 Yrs
# 998                            Bengaluru    4-9 Yrs
# 999                                   IN   5-10 Yrs
#
#                                                 skills         Dates  \
# 0    Business Intelligence\nArtificial Intelligence...    5 DAYS AGO
# 1    Data Science\nR\nNLP\nArtificial Intelligence\...    4 DAYS AGO
# 2    Predictive Modeling\nR\nData Scientist\nData M...    4 DAYS AGO
# 3    Pytorch\nTensorflow\nData Science\nNLP\nAlgori...    4 DAYS AGO
# 4    Data Science\nAzure\nData Scientist\nData Arch...    4 DAYS AGO
# ..                                                 ...           ...
# 995  Data analysis\nProduct engineering\nHTML\nData...  30+ DAYS AGO
# 996  IT Skills\nMachine Learning\nBig Data\nIT serv...   11 DAYS AGO
# 997  Azure\nBusiness Analytics\nPower Bi\nIT Skills...   11 DAYS AGO
# 998  Knowledge Sharing\nData Manipulation\nComputer...  30+ DAYS AGO
# 999  Knowledge Sharing\nData Manipulation\nComputer...  30+ DAYS AGO
#
#     PresentDate                     salary
# 0    2020-11-01    3,50,000 - 4,50,000 PA.
# 1    2020-11-01              Not disclosed
# 2    2020-11-01              Not disclosed
# 3    2020-11-01              Not disclosed
# 4    2020-11-01              Not disclosed
# ..          ...                        ...
# 995  2020-11-01              Not disclosed
# 996  2020-11-01              Not disclosed
# 997  2020-11-01  10,00,000 - 14,00,000 PA.
# 998  2020-11-01              Not disclosed
# 999  2020-11-01              Not disclosed
#
# [1000 rows x 8 columns]

# %%
df1.to_csv("naukriscrapdata.csv")

# %%
df1.columns
# Out:
# Index(['roles', 'companies', 'locations', 'experience', 'skills', 'Dates',
#        'PresentDate', 'salary'],
#       dtype='object')
